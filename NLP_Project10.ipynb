# %%
import pandas as pd
import re
import nltk
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
data = pd.read_csv("/content/Banking_Complaints.csv")

data.head()
# Out:
#    Complaint_ID                                          Complaint  \
# 0             1  My credit card payment is showing as pending. ...
# 1             2  Please help me, I have not received an update ...
# 2             3  I want to dispute a credit card charge. I woul...
# 3             4  I was charged twice for the same transaction. ...
# 4             5  The interest rate on my loan appears to be inc...
#
#       Category
# 0  Credit Card
# 1         Loan
# 2  Credit Card
# 3  Transaction
# 4         Loan

# %%
print(data.shape)
print(data.columns)
print(data.isnull().sum())
# Out:
# (1000, 3)
# Index(['Complaint_ID', 'Complaint', 'Category'], dtype='object')
# Complaint_ID    0
# Complaint       0
# Category        0
# dtype: int64

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    words = text.split()

    words = [word for word in words if word not in stop_words]

    words = [lemmatizer.lemmatize(word) for word in words]

    return " ".join(words)

# %%
data['Clean_Complaint'] = data['Complaint'].apply(clean_text)

data[['Complaint', 'Clean_Complaint']].head()
# Out:
#                                            Complaint  \
# 0  My credit card payment is showing as pending. ...
# 1  Please help me, I have not received an update ...
# 2  I want to dispute a credit card charge. I woul...
# 3  I was charged twice for the same transaction. ...
# 4  The interest rate on my loan appears to be inc...
#
#                                      Clean_Complaint
# 0  credit card payment showing pending kindly loo...
# 1       please help received update loan application
# 2  want dispute credit card charge would apprecia...
# 3  charged twice transaction please resolve soon ...
# 4  interest rate loan appears incorrect please re...

# %%
data['Category'].value_counts()
# Out:
# Category
# Credit Card           160
# Fraud                 155
# ATM                   147
# Account Management    137
# Loan                  136
# Transaction           134
# Online Banking        131
# Name: count, dtype: int64

# %%
data['Category'].value_counts().plot(kind='bar')

plt.title("Banking Complaint Categories")
plt.xlabel("Category")
plt.ylabel("Number of Complaints")
plt.xticks(rotation=45)

plt.show()

# %%
tfidf = TfidfVectorizer(max_features=20)

X = tfidf.fit_transform(data['Clean_Complaint'])

words = tfidf.get_feature_names_out()

scores = X.toarray().sum(axis=0)

result = pd.DataFrame({
    'Word': words,
    'Score': scores
})

result = result.sort_values('Score', ascending=False)

result
# Out:
#            Word       Score
# 8          help  172.616619
# 14       please  159.329157
# 13         need  122.173912
# 6     concerned  121.204893
# 0       account  112.246123
# 19        would  108.905109
# 1    appreciate  108.905109
# 5          card  108.161064
# 2    assistance  107.654209
# 12         look  103.816733
# 10       kindly  103.816733
# 9         issue  103.816733
# 17         soon  102.766489
# 15     possible  102.766489
# 16      resolve  102.766489
# 18  transaction   95.514902
# 3           atm   81.897721
# 7        credit   81.181504
# 4       banking   78.941587
# 11         loan   78.553311

# %%
result.sort_values('Score').plot(
    x='Word',
    y='Score',
    kind='barh'
)

plt.title("Frequent Banking Complaint Terms")
plt.xlabel("TF-IDF Score")

plt.show()

# %%
text = " ".join(data['Clean_Complaint'])

wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white'
).generate(text)

plt.imshow(wordcloud)

plt.axis('off')

plt.show()

# %%
total = len(data)

print("Total Complaints:", total)
# Out:
# Total Complaints: 1000

# %%
most_common = data['Category'].value_counts().idxmax()

print("Most Common Complaint Category:", most_common)
# Out:
# Most Common Complaint Category: Credit Card

# %%
category_counts = data['Category'].value_counts()

print(category_counts)
# Out:
# Category
# Credit Card           160
# Fraud                 155
# ATM                   147
# Account Management    137
# Loan                  136
# Transaction           134
# Online Banking        131
# Name: count, dtype: int64

# %%
print("BANKING COMPLAINT ANALYSIS REPORT")

print("Total Complaints:", len(data))

print("Most Common Category:",
      data['Category'].value_counts().idxmax())

print("\nComplaints by Category:")

print(data['Category'].value_counts())

print("\nMost Frequent Terms:")

print(result.head(10))
# Out:
# BANKING COMPLAINT ANALYSIS REPORT
# Total Complaints: 1000
# Most Common Category: Credit Card
#
# Complaints by Category:
# Category
# Credit Card           160
# Fraud                 155
# ATM                   147
# Account Management    137
# Loan                  136
# Transaction           134
# Online Banking        131
# Name: count, dtype: int64
#
# Most Frequent Terms:
#           Word       Score
# 8         help  172.616619
# 14      please  159.329157
# 13        need  122.173912
# 6    concerned  121.204893
# 0      account  112.246123
# 19       would  108.905109
# 1   appreciate  108.905109
# 5         card  108.161064
# 2   assistance  107.654209
# 12        look  103.816733
